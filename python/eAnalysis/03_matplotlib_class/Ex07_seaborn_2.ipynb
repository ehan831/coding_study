# %% [markdown]
# ### 1. 산점도 그래프
#
#    (1) matplotlib의 subplots()로 기본 틀 만들고 seaborn의 그래프 함수 이용
#
#     회귀선 제거 : fit_reg=False
#      axes = sb.regplot(x='total_bill', y='tip', data=tips, fit_reg=False)
#
#      [예] 지불 금액과 팁에 대한 그래프
#
#
#    (2) 산점도와 히스토그램을 한번에 - jointplot()
#
#       ` 산점도 그래프의 데이타를 육각(hexbin)으로 구분 : kind='hex'속성
#           ( 개수가 많아지면 진한 색으로 표시 )
#           axes = sb.jointplot(x='total_bill', y='tip', data=tips, kind='hex')
#
#
#
# ###  2. 이차원 밀집도 그래프 (등고선그래프) - kdeplot()
#
#
# ###  3. 막대그래프 - barplot() / countplot()
#
#      * 이산형 데이타(명목데이타)
#
#      [예] 시간에 따란 비불한 비용의 평균 그래프
#
#
# ###  4. 박스그래프 - boxplot()
#      : 최소값, 4분위수, 평균값, 이상치 등의 통계량을 한번에 표현하는 그래프
#
#      - 1분위수와 3분위수를 박스로 그려짐
#      - 박스 내부의 선은 중앙값이다 (평균값이 아님)
#      - 박수 외부의 선은 최솟값과 최댓값인데
#          ` 최솟값 : 1분위수 - ( IQR * 1.5 )
#          ` 최댓값 : 3분위수 + ( IQR * 1.5 )
#          ` IQR = 3분위수 - 1분위수
#      - 선 밖의 점은 outlier로 결측치이다
#
#
# ###  5. 바이올린 그래프 - violinplot()
#      : 박스 그래스는 통계 수치를 확인하기 위해 자주 사용되지만 데이터 분산이 모호하기에
#        박스 그래스에 커널 밀도를 표현한 그래프
#
#
# ###  6. 관계 그래프 - pairplot()
#
#     [그래프 분석]
#     1. 데이타셋에서 연속형 데이타로 된 컬럼
#     2. 동일 컬럼인경우 즉 하나의 변수이기에 히스토그램으로 나옴
#     3. 다른 변수와의 결합은 이차원 그래프로 산점도 그래프로 나옴
#     4. 대각선으로는 동일한 결과

# %%
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset('tips')

# %% [markdown]
# ## 1. 산점도 그래프
#
# ### (1) matplotlib의 subplots()로 기본 틀 만들고 seaborn의 그래프 함수 이용
#
#     회귀선 제거 : fit_reg=False
#      axes = sb.regplot(x='total_bill', y='tip', data=tips, fit_reg=False)
#
#      [예] 지불 금액과 팁에 대한 그래프

# %%
plt.subplot
axes = sns.regplot(x='total_bill', y='tip', data=tips)

# %% [markdown]
# ###    (2) 산점도와 히스토그램을 한번에 - jointplot()
#
#       ` 산점도 그래프의 데이타를 육각(hexbin)으로 구분 : kind='hex'속성
#           ( 개수가 많아지면 진한 색으로 표시 )
#           axes = sb.jointplot(x='total_bill', y='tip', data=tips, kind='hex')

# %%
plt.subplot
axes = sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex')
# Out:
# /Users/eunguhan/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /Users/eunguhan/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ##  2. 이차원 밀집도 그래프 (등고선그래프) - kdeplot()
#
#     [참고] 함수의 도움말 : 함수에 커서 놓고 ctrl + tab

# %%
plt.subplot
ax = sns.kdeplot(data=tips['total_bill'], data2=tips['tip'], shade=True, vertical=True, legend=False, shade_lowest=False, cbar=True)

# %% [markdown]
# ##  3. 막대그래프 - barplot()
#
#      * 이산형 데이타(명목데이타)
#
#      [예] 시간대('time')에 따라 지불한 비용의 평균 그래프

# %%
plt.subplot
ax = sns.barplot(x=tips['time'], y=tips['total_bill'])

# %% [markdown]
# ##  4. 박스그래프 - boxplot()
#      : 최소값, 4분위수, 평균값, 이상치 등의 통계량을 한번에 표현하는 그래프
#
#      - 1분위수와 3분위수를 박스로 그려짐
#      - 박스 내부의 선은 중앙값이다 (평균값이 아님)
#      - 박수 외부의 선은 최솟값과 최댓값인데
#          ` 최솟값 : 1분위수 - ( IQR * 1.5 )
#          ` 최댓값 : 3분위수 + ( IQR * 1.5 )
#          ` IQR = 3분위수 - 1분위수
#      - 선 밖의 점은 outlier로 결측치이다

# %% [markdown]
# <img src="https://i.imgur.com/CnFsXL9.png" width=450>

# %%
plt.subplot
ax = sns.boxplot(x=tips['time'], y=tips['total_bill'])

# %% [markdown]
# ##  5. 바이올린 그래프 - violinplot()
#      : 박스 그래스는 통계 수치를 확인하기 위해 자주 사용되지만 데이터 분산이 모호하기에
#        박스 그래스에 커널 밀도를 표현한 그래프

# %%
plt.subplot
ax = sns.violinplot(x=tips['time'], y=tips['total_bill'])

# %% [markdown]
# ##  6. 관계 그래프 - pairplot()
#
#     [그래프 분석]
#     1. 데이타셋에서 연속형 데이타로 된 컬럼
#     2. 동일 컬럼인경우 즉 하나의 변수이기에 히스토그램으로 나옴
#     3. 다른 변수와의 결합은 이차원 그래프로 산점도 그래프로 나옴
#     4. 대각선으로는 동일한 결과

# %%
sns.pairplot(tips)

pair_grid = sns.PairGrid(tips)
pair_grid.map_upper(sns.regplot)
pair_grid.map_lower(sns.kdeplot)
pair_grid.map_diag(sns.distplot)
# Out:
# /Users/eunguhan/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /Users/eunguhan/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /Users/eunguhan/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /Users/eunguhan/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /Users/eunguhan/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /Users/eunguhan/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

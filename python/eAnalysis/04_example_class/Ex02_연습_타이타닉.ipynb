# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import seaborn as sns

# 한글깨짐처리
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
# 데이타 로딩 - 기존 데이타셋과 다르기에 확인 필요
raw_data = pd.read_csv('./data/titanic.csv')
# raw_data.info()

# raw_data.describe()
raw_data.sort_values('Age')
# Out:
#      PassengerId  Survived  Pclass  \
# 298          299         1       1
# 475          476         0       1
# 740          741         1       1
# 264          265         0       3
# 613          614         0       3
# 739          740         0       3
# 470          471         0       3
# 270          271         0       1
# 738          739         0       3
# 468          469         0       3
# 274          275         1       3
# 260          261         0       3
# 466          467         0       2
# 277          278         0       2
# 888          889         0       3
# 727          728         1       3
# 284          285         0       1
# 464          465         0       3
# 286          287         1       3
# 726          727         1       2
# 629          630         0       3
# 295          296         0       1
# 573          574         1       3
# 732          733         0       2
# 481          482         0       2
# ...

# %% [markdown]
# ##  생존자와 사망자의 시각화

# %%
raw_data.columns
raw_data.head()
raw_data['생존여부'] = np.where(raw_data['Survived'] == 0, '사망', '생존')
data = raw_data.groupby('Survived').count()

plt.bar(["사망", "생존"], data['생존여부'])
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# # 연령분포 시각화

# %%
raw_data['AgeCeil'] = raw_data['Age'].apply(np.ceil).astype(int)
data2 = raw_data.sort_values('AgeCeil')
data2 = data2.groupby('AgeCeil').count()
# plt.plot(data2['PassengerId'])
plt.bar(data2.index, data2['PassengerId'])
# Out:
# <BarContainer object of 70 artists>

# %% [markdown]
# # 객실등급별로 각 평균 통계 - 표

# %%
data3 = raw_data.groupby('Pclass').count()
data3
plt.bar(data3.index, data3['PassengerId'])
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# # 성별, 연령대, 객실등급별 생존자 시각화

# %%
# 하는 중

# %% [markdown]
# # 상관관계 분석하여 해석하기

# %%
# 하는 중
